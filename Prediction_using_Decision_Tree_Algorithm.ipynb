# %% [markdown]
# ***Prediction using Decision Tree Algorithm***
#
# 1. **dataset**:Iris genome has three species.The feature such as length and colour of the petal are present in the table.
# 2. **Target**: To Predict the species of the flower given the inputs
# 3. **Model**: Using DTC(Decision Tree Classfier)
# ---
# BY *ASHISH BENNY*

# %% [markdown]
# ##importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the dataset

# %%
df=pd.read_csv('/content/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df=df.drop(columns=['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ##Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
df.Species.value_counts()
#the data is balanced so no need to using oversampling technique
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64

# %% [markdown]
# ##Train split

# %%
X=df.drop(columns='Species',axis=1)
y=df.Species

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)

# %% [markdown]
# ##Training the model

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict_test=dtree.predict(X_test)
y_predict_train=dtree.predict(X_train)

# %% [markdown]
# ##Evaluation of DTC

# %%
pd.crosstab(y_test,y_predict_test)
# Out:
# col_0     0   1   2
# Species
# 0        40   0   0
# 1         0  28   5
# 2         0   3  29

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print('Testing Accuracy = ', accuracy_score(y_test,y_predict_test))
print('Training Accuracy = ', accuracy_score(y_train,y_predict_train))
# Out:
# Testing Accuracy =  0.9238095238095239
# Training Accuracy =  1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
